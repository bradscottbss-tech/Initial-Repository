# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
## Write your code here
df.info()
df.describe()
#print(df.columns)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# ...

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
## Write your code here
total_missing_values = df.isnull().sum().sum()
print(f"Total missing values in the DataFrame: {total_missing_values}")

missing_counts = df.isnull().sum()
print("Missing values per column:")
print(missing_counts)

print(f"Percent Missing Values: {(total_missing_values/(len(df)*len(df.columns))*100)}%")
# Out:
# Total missing values in the DataFrame: 2890957
# Missing values per column:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64
# Percent Missing Values: 38.75372026502523%

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
## Write your code here
print(f"Total Rows = {(len(df))}")

missing_employ_values = df['Employment'].isnull().sum()
print(f"Number of missing values in the 'Employment' column: {missing_employ_values}")
print(f"Percent Missing Employment Values: {(missing_employ_values/(len(df))*100):.1f}%")

missing_jobsat_values = df['JobSat'].isnull().sum()
print(f"Number of missing values in the 'JobSat' column: {missing_jobsat_values}")
print(f"Percent Missing JobSat Values: {(missing_jobsat_values/(len(df))*100):.1f}%")

missing_yearscodepro_values = df['YearsCodePro'].isnull().sum()
print(f"Number of missing values in the 'YearsCodePro' column: {missing_yearscodepro_values}")
print(f"Percent Missing YearsCodePro Values: {(missing_yearscodepro_values/(len(df))*100):.1f}%")
# Out:
# Total Rows = 65437
# Number of missing values in the 'Employment' column: 0
# Percent Missing Employment Values: 0.0%
# Number of missing values in the 'JobSat' column: 36311
# Percent Missing JobSat Values: 55.5%
# Number of missing values in the 'YearsCodePro' column: 13827
# Percent Missing YearsCodePro Values: 21.1%

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
## Write your code here
# Calculate the frequency of each category in the 'JobSat' column
jobsat_counts = df['JobSat'].value_counts()

plt.figure(figsize=(6, 6))

jobsat_counts.plot.pie(autopct='%1.1f%%', startangle=90)

plt.title('Job Satisfaction Distribution')
plt.axis('equal')

plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
## Write your code here
# count frequency of 'LanguageHaveWorkedWith'
# save top 10 'LanguageHaveWorkedWith' as 'top_10_worked'
# count frequency of 'LanguageWantToWorkWith'
# save top 10 'LanguageWantToWorkWith' as 'top_10_wantwork'
# print 'top_10_worked'
# print 'top_10_wantwork'

#Count frequency of 'LanguageHaveWorkedWith'
# Split by ';' because they are in a single string, then explode to list
worked_counts = df['LanguageHaveWorkedWith'].str.split(';').explode().value_counts()

#Save top 10 'LanguageHaveWorkedWith'
top_10_worked = worked_counts.head(10)

#Count frequency of 'LanguageWantToWorkWith'
wantwork_counts = df['LanguageWantToWorkWith'].str.split(';').explode().value_counts()

#Save top 10 'LanguageWantToWorkWith'
top_10_wantwork = wantwork_counts.head(10)

#Print 'top_10_worked'
print("Top 10 Languages Worked With:")
print(top_10_worked)

#Print 'top_10_wantwork'
print("\nTop 10 Languages Want To Work With:")
print(top_10_wantwork)
# Out:
# Top 10 Languages Worked With:
# LanguageHaveWorkedWith
# JavaScript                 37492
# HTML/CSS                   31816
# Python                     30719
# SQL                        30682
# TypeScript                 23150
# Bash/Shell (all shells)    20412
# Java                       18239
# C#                         16318
# C++                        13827
# C                          12184
# Name: count, dtype: int64
#
# Top 10 Languages Want To Work With:
# LanguageWantToWorkWith
# Python                     25047
# JavaScript                 23774
# SQL                        22400
# HTML/CSS                   20721
# TypeScript                 20239
# Rust                       17232
# Go                         13837
# Bash/Shell (all shells)    13744
# C#                         12921
# C++                        10873
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
## Write your code here
#Pivot Table to get counts for grouped bar chart
pivot_df = df.groupby(['Country', 'RemoteWork']).size().unstack(fill_value=0)

#Plot
ax = pivot_df.plot.bar(figsize=(10, 6), rot=90)
ax.tick_params(axis='x', labelsize=6)
plt.title('Remote Work Distribution by Country')
plt.ylabel('Count')
plt.xlabel('Country')
plt.legend(title='Remote Work Type')
plt.show()

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
## Write your code here
#Change text to specific numbers
df['YearsCodePro'] = df['YearsCodePro'].replace({'Less than 1 year': 0, 'More than 50 years': 51})

new_df = df[['JobSat', 'YearsCodePro']].copy()
new_df = new_df.dropna()
new_df = new_df.apply(pd.to_numeric, errors='coerce')
#new_df.head(20)

plt.figure(figsize=(10, 6))
plt.scatter(new_df['YearsCodePro'], new_df['JobSat'], alpha=0.5)
plt.title('Job Satisfaction vs Years of Professional Coding')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Job Satisfaction')
plt.show()

correlation = new_df['YearsCodePro'].corr(new_df['JobSat'], method='pearson')
print(f"Pearson Correlation: {correlation}")
# Out:
# Pearson Correlation: 0.10415320964659897

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
## Write your code here
print(f"Total Rows = {(len(df))}")

missing_employ_values = df['Employment'].isnull().sum()
print(f"Number of missing values in the 'Employment' column: {missing_employ_values}")
print(f"Percent Missing Employment Values: {(missing_employ_values/(len(df))*100):.1f}%")

missing_EdLevel_values = df['EdLevel'].isnull().sum()
print(f"Number of missing values in the 'EdLevel' column: {missing_EdLevel_values}")
print(f"Percent Missing EdLevel Values: {(missing_EdLevel_values/(len(df))*100):.1f}%")

new2_df = df[['Employment', 'EdLevel']].copy()
new2_df = new2_df.dropna()
#new2_df.head(20)

ctab = pd.crosstab(new2_df['Employment'], new2_df['EdLevel'])

# Optional: Add margins (totals) and normalize for percentages
# ctab = pd.crosstab(new2_df['Employment'], new2_df['Level'], margins=True, normalize='index')

print(ctab)
# Out:
# Total Rows = 65437
# Number of missing values in the 'Employment' column: 0
# Percent Missing Employment Values: 0.0%
# Number of missing values in the 'EdLevel' column: 4653
# Percent Missing EdLevel Values: 7.1%
# EdLevel                                             Associate degree (A.A., A.S., etc.)  \
# Employment
# Employed, full-time                                                                1059
# Employed, full-time;Employed, part-time                                               9
# Employed, full-time;Independent contractor, fre...                                  104
# Employed, full-time;Independent contractor, fre...                                   11
# Employed, full-time;Independent contractor, fre...                                    0
# ...                                                                                 ...
# Student, full-time;Student, part-time;Employed,...                                    0
# ...

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here
clean_df=df

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
